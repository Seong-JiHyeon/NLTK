# %% [markdown]
# <a href="https://colab.research.google.com/github/Seong-JiHyeon/NLTK/blob/master/Pos_tagging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# POS (Part Of Speeching)
#
# POS-tagging
#
# parsing -> tree

# %% [markdown]
# 품사 태깅 방법 이견:
#
# * Rule-Based (Learn-Based)
# * **Statistical models (Rule learning)**
#
# 다음 나올 말은? 마코프 모델

# %% [markdown]
# Tagging(태깅): 중의성을 해소하기 위한 부가적 언어 정보 부착
#
# Tagger(태거): 태깅을 수행하는 컴퓨터 프로그램
#
# Tagged corpus(부착말뭉치): 태그가 부착된 말뭉치 (ex. brown corpus)

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
# ...
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
# ...

# %%
s = ['time', 'flies', 'like', 'an', 'arrow'] #제대로된 결과가 안나옴
nltk.pos_tag(s)
# Out:
# [('time', 'NN'),
#  ('flies', 'NNS'),
#  ('like', 'IN'),
#  ('an', 'DT'),
#  ('arrow', 'NN')]

# %%
nltk.pos_tag(s, tagset='universal')
# Out:
# [('time', 'NOUN'),
#  ('flies', 'NOUN'),
#  ('like', 'ADP'),
#  ('an', 'DET'),
#  ('arrow', 'NOUN')]

# %% [markdown]
# * Universal Tag Sets
#
# >ADJ: adjective (new, good, high..)
# >
# >ADP: adposition (on, of, at, with..)
# >
# >ADV: adverb (really, already, still..)
# >
# >CONJ: conjunction (and, or, but..)
# >
# >DET: determiner, article (the, a, some, most, every, no, which..)
# >
# >NOUN: noun (year, home, costs, time..)
# >
# >NUM: numeral (twenty-four, fourth, 1991..)
# >
# >PRT: particle (at, on, out, over..)
# >
# >PRON: pronoun (he, their, her, its..)
# >
# >VERB: verb (is, say, told, given..)
# >
# >.: punctuation marks (. , ; ! )
# >
# >x: other (university, dunno, gr8..)

# %%
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %%
from nltk.corpus import*
t = nltk.word_tokenize("They refused to permit us to obtain the refuse permit")

# %%
nltk.pos_tag(t)
# Out:
# [('They', 'PRP'),
#  ('refused', 'VBD'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN')]

# %%
# automatic tagging <- need data
tagged_token = nltk.tag.str2tuple('fly/NN')
tagged_token
# Out:
# ('fly', 'NN')

# %%
#tag to string tuple
tagged_sent = 'Time/NN flies/VBD like/IN an/DT arrow/NN ./.'
[nltk.tag.str2tuple(t) for t in tagged_sent.split()]
# Out:
# [('Time', 'NN'),
#  ('flies', 'VBD'),
#  ('like', 'IN'),
#  ('an', 'DT'),
#  ('arrow', 'NN'),
#  ('.', '.')]

# %%
#brown, nps_chat, conll2000, treebank
b = brown.words()

# %%
type(b)
# Out:
# nltk.corpus.reader.util.ConcatenatedCorpusView

# %%
b_tagged=brown.tagged_words()
b_tagged[:30]
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'CS'),
#  ('any', 'DTI'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.'),
#  ('The', 'AT'),
#  ('jury', 'NN'),
#  ('further', 'RBR'),
#  ('said', 'VBD'),
#  ('in', 'IN')]

# %%
#brown corpus news category에서 가장 많이 나오는 품사 찾기
brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')

# %%
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)

# %%
tag_fd.most_common()
# Out:
# [('NOUN', 30654),
#  ('VERB', 14399),
#  ('ADP', 12355),
#  ('.', 11928),
#  ('DET', 11389),
#  ('ADJ', 6706),
#  ('ADV', 3349),
#  ('CONJ', 2717),
#  ('PRON', 2535),
#  ('PRT', 2264),
#  ('NUM', 2166),
#  ('X', 92)]

# %%
tag_fd.plot(cumulative=True)

# %%
#명사 앞에 가장 자주 출현하는 단어 품사 찾기
word_tag_pairs = nltk.bigrams(brown_news_tagged)
noun_preceders = [a[1] for (a,b) in word_tag_pairs if b[1]=='NOUN'] #index=1은 각 단어의 tag
fdist = nltk.FreqDist(noun_preceders)
[tag for (tag, _) in fdist.most_common()]
# Out:
# ['NOUN',
#  'DET',
#  'ADJ',
#  'ADP',
#  '.',
#  'VERB',
#  'CONJ',
#  'NUM',
#  'ADV',
#  'PRT',
#  'PRON',
#  'X']

# %%
#뉴스 카테고리에서 가장 빈번한 동사군들 찾기
wsj = nltk.corpus.treebank.tagged_words(tagset='universal')
word_tag_fd = nltk.FreqDist(wsj)
[wt[0] for (wt, _) in word_tag_fd.most_common() if wt[1]=='VERB']
# Out:
# ['is',
#  'said',
#  'was',
#  'are',
#  'be',
#  'has',
#  'have',
#  'will',
#  'says',
#  'would',
#  'were',
#  'had',
#  'been',
#  'could',
#  "'s",
#  'can',
#  'do',
#  'say',
#  'make',
#  'may',
#  'did',
#  'rose',
#  'made',
#  'does',
#  'expected',
#  'buy',
#  'take',
#  'get',
#  'might',
#  'sell',
#  'added',
#  'sold',
#  'help',
#  'including',
#  'should',
#  'reported',
#  'according',
#  'pay',
#  'compared',
#  'being',
#  'fell',
#  'began',
#  'based',
#  'used',
#  'closed',
#  "'re",
#  'want',
#  'see',
#  'took',
#  'yield',
#  'offered',
#  'set',
#  'priced',
#  'approved',
#  'come',
#  'noted',
#  'cut',
#  'ended',
#  'found',
#  'increased',
#  'become',
#  'think',
#  'named',
#  'go',
#  'trying',
#  'proposed',
#  'received',
#  'growing',
#  'declined',
#  'held',
#  'give',
#  'came',
#  'use',
#  'put',
#  'making',
#  'continue',
#  'raise',
#  'estimated',
#  'called',
#  'paid',
#  'designed',
#  'going',
#  'expects',
#  'seeking',
# ...

# %%
cfd1 = nltk.ConditionalFreqDist(wsj) #wsj가 튜플 형태기 때문에 ConditionalFreqDist 사용
cfd1['yield'].most_common()
# Out:
# [('VERB', 28), ('NOUN', 20)]

# %%
cfd1['cut'].most_common()
# Out:
# [('VERB', 25), ('NOUN', 3)]

# %%
cfd1['cut']
# Out:
# FreqDist({'NOUN': 3, 'VERB': 25})

# %%
# VBD(과거형), VBN(과거분사형) 태그를 동시에 가지는 단어와 그 주변 텍스트
wsj = nltk.corpus.treebank.tagged_words()
cfd2 = nltk.ConditionalFreqDist(wsj)
[w for w in cfd2.conditions() if 'VBD' in cfd2[w] and 'VBN' in cfd2[w]]
# Out:
# ['named',
#  'used',
#  'caused',
#  'reported',
#  'said',
#  'stopped',
#  'heard',
#  'studied',
#  'led',
#  'replaced',
#  'sold',
#  'worked',
#  'died',
#  'found',
#  'rejected',
#  'imposed',
#  'made',
#  'dumped',
#  'imported',
#  'mixed',
#  'described',
#  'continued',
#  'ended',
#  'thought',
#  'reached',
#  'had',
#  'approved',
#  'completed',
#  'suspended',
#  'lifted',
#  'dropped',
#  'voted',
#  'settled',
#  'decided',
#  'followed',
#  'welcomed',
#  'held',
#  'banned',
#  'pointed',
#  'squeezed',
#  'fed',
#  'registered',
#  'released',
#  'increased',
#  'forecast',
#  'recorded',
#  'announced',
#  'offered',
#  'lowered',
#  'spent',
#  'proposed',
#  'got',
#  'added',
#  'noted',
#  'turned',
#  'closed',
#  'retired',
#  'ordered',
#  'required',
#  'received',
#  'moved',
#  'determined',
#  'changed',
#  'upheld',
#  'set',
#  'estimated',
#  'compared',
#  'opened',
#  'tied',
#  'filed',
#  'disclosed',
#  'anticipated',
#  'attached',
# ...

# %%
idx1 = wsj.index(('kicked', 'VBD')) #주변 단어
wsj[idx1-4:idx1+1]
# Out:
# [('While', 'IN'),
#  ('program', 'NN'),
#  ('trades', 'NNS'),
#  ('swiftly', 'RB'),
#  ('kicked', 'VBD')]

# %%
idx2 = wsj.index(('kicked', 'VBN')) #주변 단어
wsj[idx2-4:idx2+1]
# Out:
# [('head', 'NN'),
#  ('of', 'IN'),
#  ('state', 'NN'),
#  ('has', 'VBZ'),
#  ('kicked', 'VBN')]

# %%
# 'NN'으로 시작하는 태그와 관련 단어들 리스트하기
def findtags(tag_prefix, tagged_text):
  cfd=nltk.ConditionalFreqDist((tag, word) for (word, tag) in tagged_text
                               if tag.startswith(tag_prefix))
  return dict((tag, cfd[tag].most_common(5)) for tag in cfd.conditions())

# %%
tagdict = findtags('NN', nltk.corpus.brown.tagged_words(categories='news'))

# %%
for tag in sorted(tagdict):
  print(tag, tagdict[tag])
# Out:
# NN [('year', 137), ('time', 97), ('state', 88), ('week', 85), ('man', 72)]
# NN$ [("year's", 13), ("world's", 8), ("state's", 7), ("nation's", 6), ("city's", 6)]
# NN$-HL [("Golf's", 1), ("Navy's", 1)]
# NN$-TL [("President's", 11), ("Administration's", 3), ("Army's", 3), ("League's", 3), ("University's", 3)]
# NN-HL [('sp.', 2), ('problem', 2), ('Question', 2), ('cut', 2), ('party', 2)]
# NN-NC [('ova', 1), ('eva', 1), ('aya', 1)]
# NN-TL [('President', 88), ('House', 68), ('State', 59), ('University', 42), ('City', 41)]
# NN-TL-HL [('Fort', 2), ('Mayor', 1), ('Commissioner', 1), ('City', 1), ('Oak', 1)]
# NNS [('years', 101), ('members', 69), ('people', 52), ('sales', 51), ('men', 46)]
# NNS$ [("children's", 7), ("women's", 5), ("men's", 3), ("janitors'", 3), ("taxpayers'", 2)]
# NNS$-HL [("Dealers'", 1), ("Idols'", 1)]
# NNS$-TL [("Women's", 4), ("States'", 3), ("Giants'", 2), ("Princes'", 1), ("Bombers'", 1)]
# ...

# %%
# often 주변 단어 품사 연구
brown_learned_text = brown.words(categories='learned')
sorted(set(b for (a,b) in nltk.bigrams(brown_learned_text) if a=='often'))
# Out:
# [',',
#  '.',
#  'accomplished',
#  'analytically',
#  'appear',
#  'apt',
#  'associated',
#  'assuming',
#  'became',
#  'become',
#  'been',
#  'began',
#  'call',
#  'called',
#  'carefully',
#  'chose',
#  'classified',
#  'colorful',
#  'composed',
#  'contain',
#  'differed',
#  'difficult',
#  'encountered',
#  'enough',
#  'equate',
#  'extremely',
#  'found',
#  'happens',
#  'have',
#  'ignored',
#  'in',
#  'involved',
#  'more',
#  'needed',
#  'nightly',
#  'observed',
#  'of',
#  'on',
#  'out',
#  'quite',
#  'represent',
#  'responsible',
#  'revamped',
#  'seclude',
#  'set',
#  'shortened',
#  'sing',
#  'sounded',
#  'stated',
#  'still',
#  'sung',
#  'supported',
#  'than',
#  'to',
#  'when',
#  'work']

# %%
brown_lrnd_tagged = brown.tagged_words(categories='learned', tagset='universal')
tags = [b[1] for (a,b) in nltk.bigrams(brown_lrnd_tagged) if a[0]=='often']
fd = nltk.FreqDist(tags)
fd.tabulate()
# Out:
# VERB  ADV  ADP  ADJ    .  PRT
#   37    8    7    6    4    2

# %%
# verb to verb 구문 형태 모두 찾아내기
def process(sentence):
  for (w1,t1),(w2,t2),(w3,t3) in nltk.trigrams(sentence):
    if(t1.startswith('V') and t2=='TO' and t3.startswith('V')):
      print(w1,w2,w3)

# %%
for tagged_sent in brown.tagged_sents():
  process(tagged_sent)
# Out:
# combined to achieve
# continue to place
# serve to protect
# wanted to wait
# allowed to place
# expected to become
# expected to approve
# expected to make
# intends to make
# seek to set
# like to see
# designed to provide
# get to hear
# expects to tell
# expected to give
# prefer to pay
# required to obtain
# permitted to teach
# designed to reduce
# Asked to elaborate
# got to go
# raised to pay
# scheduled to go
# cut to meet
# needed to meet
# hastened to add
# found to prevent
# continue to insist
# compelled to make
# made to remove
# revamped to give
# want to risk
# appear to spark
# fails to consider
# plans to call
# going to examine
# plans to name
# come to pass
# voted to accept
# happens to hold
# authorized to adopt
# hesitated to prosecute
# try to make
# decided to spend
# taken to preserve
# left to preserve
# stand to bring
# decided to seek
# trying to induce
# proposing to make
# decided to run
# directed to investigate
# expected to pass
# expected to make
# ...

# %%
# python dictionary with pos-tagging
pos = {'colorless': 'ADJ', 'ideas': 'N', 'sleep': 'V', 'furiously': 'ADV'}
pos['colorless']
# Out:
# 'ADJ'

# %%
pos['blog'] #없는 key를 입력한 경우 error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-366538269ae9> in <module>()
# ----> 1 pos['blog'] #없는 key를 입력한 경우 error
#
# KeyError: 'blog'

# %%
from collections import defaultdict

# %%
pos = defaultdict(lambda: 'NOUN')

# %%
pos['ideas']='N'
pos['colorless']='ADJ'

# %%
pos
# Out:
# defaultdict(<function __main__.<lambda>>, {'colorless': 'ADJ', 'ideas': 'N'})

# %%
pos['blog'] #default 처리됨
# Out:
# 'NOUN'

# %%
pos
# Out:
# defaultdict(<function __main__.<lambda>>,
#             {'blog': 'NOUN', 'colorless': 'ADJ', 'ideas': 'N'})

# %%
counts = defaultdict(int) #0을 default 값으로

# %%
#품사 빈도수
for (word, tag) in brown.tagged_words(categories='news', tagset='universal'):
  counts[tag] +=1

# %%
counts['NOUN']
# Out:
# 30654

# %%
sorted(counts) #알파벳 순으로 정렬됨
# Out:
# ['.',
#  'ADJ',
#  'ADP',
#  'ADV',
#  'CONJ',
#  'DET',
#  'NOUN',
#  'NUM',
#  'PRON',
#  'PRT',
#  'VERB',
#  'X']

# %%
from operator import itemgetter #items -> dictionary에서 tuple로 형태를 바꿔줌
sorted(counts.items(), key=itemgetter(1), reverse=True) #역순(가장 많은 순부터)
# Out:
# [('NOUN', 30654),
#  ('VERB', 14399),
#  ('ADP', 12355),
#  ('.', 11928),
#  ('DET', 11389),
#  ('ADJ', 6706),
#  ('ADV', 3349),
#  ('CONJ', 2717),
#  ('PRON', 2535),
#  ('PRT', 2264),
#  ('NUM', 2166),
#  ('X', 92)]

# %%
[t for t,c in sorted(counts.items(), key=itemgetter(1), reverse=True)] #itemgetter는 sorting의 기준을 정함 (0=알파벳 순) => n번째 아이템을 기준으로
# Out:
# ['NOUN',
#  'VERB',
#  'ADP',
#  '.',
#  'DET',
#  'ADJ',
#  'ADV',
#  'CONJ',
#  'PRON',
#  'PRT',
#  'NUM',
#  'X']

# %%
# 특정 (단어의 품사, 다음 단어) 당 다음에 나오는 단어의 품사 개수
pos = defaultdict(lambda: defaultdict(int)) #그냥 int만 넣으면 iterable X
brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
for ((w1, t1), (w2,t2)) in nltk.bigrams(brown_news_tagged):
  pos[(t1,w2)][t2] +=1

# %%
pos[('DET', 'right')]
# Out:
# defaultdict(int, {'ADJ': 11, 'NOUN': 5})

# %%
last_letters = defaultdict(list)
words = nltk.corpus.words.words('en')
for word in words:
  key=word[-2:] #단어 끝의 두 글자
  last_letters[key].append(word)

# %%
last_letters['ly']
# Out:
# ['abactinally',
#  'abandonedly',
#  'abasedly',
#  'abashedly',
#  'abashlessly',
#  'abbreviately',
#  'abdominally',
#  'abhorrently',
#  'abidingly',
#  'abiogenetically',
#  'abiologically',
#  'abjectly',
#  'ableptically',
#  'ably',
#  'abnormally',
#  'abominably',
#  'aborally',
#  'aboriginally',
#  'abortively',
#  'aboundingly',
#  'abridgedly',
#  'abruptedly',
#  'abruptly',
#  'abscondedly',
#  'absently',
#  'absentmindedly',
#  'absolutely',
#  'absolutistically',
#  'absorbedly',
#  'absorbingly',
#  'absorptively',
#  'abstemiously',
#  'abstinently',
#  'abstractedly',
#  'abstractively',
#  'abstractly',
#  'abstrusely',
#  'absurdly',
#  'abundantly',
#  'abusedly',
#  'abusefully',
#  'abusively',
#  'abysmally',
#  'academically',
#  'acceleratedly',
#  'accentually',
#  'acceptably',
#  'acceptedly',
#  'accessarily',
#  'accessibly',
#  'accessively',
#  'accessorily',
#  'accidentally',
#  'accidently',
#  'accommodately',
#  'accommodatingly',
# ...

# %%
brown_tagged = brown.tagged_words(tagset='universal')

# %%
cfd = nltk.ConditionalFreqDist(brown_tagged)

# %%
cfd['time']
# Out:
# FreqDist({'NOUN': 1555, 'VERB': 1})

# %%
cfd['flies'] #원형 변형 후 tagging하면 더 정확함
# Out:
# FreqDist({'NOUN': 7, 'VERB': 4})

# %%
# tagging을 할 때는 문장단위로 한 게 좋음 (tagged_sents)
# Default Tagger
tags = [tag for (word, tag) in brown.tagged_words(categories='news')]
nltk.FreqDist(tags).max()
# Out:
# 'NN'

# %%
from nltk.tokenize import *
raw = 'I do not like green eggs and ham, I do not like them Sam I am!'
tokens = word_tokenize(raw)
default_tagger = nltk.DefaultTagger('NN')
default_tagger.tag(tokens)
# Out:
# [('I', 'NN'),
#  ('do', 'NN'),
#  ('not', 'NN'),
#  ('like', 'NN'),
#  ('green', 'NN'),
#  ('eggs', 'NN'),
#  ('and', 'NN'),
#  ('ham', 'NN'),
#  (',', 'NN'),
#  ('I', 'NN'),
#  ('do', 'NN'),
#  ('not', 'NN'),
#  ('like', 'NN'),
#  ('them', 'NN'),
#  ('Sam', 'NN'),
#  ('I', 'NN'),
#  ('am', 'NN'),
#  ('!', 'NN')]

# %%
brown_tagged_sents = brown.tagged_sents()
default_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.13130472824476916

# %%
#regular expression tag
patterns=[
          (r'.*ing$', 'VBG'),
          (r'.*ed$', 'VBD'),
          (r'.*es$', 'VBZ'),
          (r'.*ould$', 'MD'),
          (r'.*\'s$', 'NN$'),
          (r'.*s$', 'NNS'),
          (r'.*', 'NN'),
]

# %%
brown_sents = brown.sents()
regexp_tagger = nltk.RegexpTagger(patterns)
regexp_tagger.tag(brown_sents[3])
# Out:
# [('``', 'NN'),
#  ('Only', 'NN'),
#  ('a', 'NN'),
#  ('relative', 'NN'),
#  ('handful', 'NN'),
#  ('of', 'NN'),
#  ('such', 'NN'),
#  ('reports', 'NNS'),
#  ('was', 'NNS'),
#  ('received', 'VBD'),
#  ("''", 'NN'),
#  (',', 'NN'),
#  ('the', 'NN'),
#  ('jury', 'NN'),
#  ('said', 'NN'),
#  (',', 'NN'),
#  ('``', 'NN'),
#  ('considering', 'VBG'),
#  ('the', 'NN'),
#  ('widespread', 'NN'),
#  ('interest', 'NN'),
#  ('in', 'NN'),
#  ('the', 'NN'),
#  ('election', 'NN'),
#  (',', 'NN'),
#  ('the', 'NN'),
#  ('number', 'NN'),
#  ('of', 'NN'),
#  ('voters', 'NNS'),
#  ('and', 'NN'),
#  ('the', 'NN'),
#  ('size', 'NN'),
#  ('of', 'NN'),
#  ('this', 'NNS'),
#  ('city', 'NN'),
#  ("''", 'NN'),
#  ('.', 'NN')]

# %%
regexp_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.19019679777332257

# %%
# unigram tagger
fd = nltk.FreqDist(brown.words(categories='news'))
cfd = nltk.ConditionalFreqDist(brown.tagged_words(categories='news'))
most_freq_words = fd.most_common(100)
likely_tags = dict((word, cfd[word].max()) for (word, _) in most_freq_words)
baseline_tagger = nltk.UnigramTagger(model=likely_tags)
baseline_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.4696708210184018

# %%
# backoff tagging
baseline_tagger = nltk.UnigramTagger(model=likely_tags, backoff=nltk.DefaultTagger('NN'))

# %%
# unigram tagging: training
unigram_tagger = nltk.UnigramTagger(brown_tagged_sents)
unigram_tagger.tag(brown_sents[2007])
# Out:
# [('Various', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('apartments', 'NNS'),
#  ('are', 'BER'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('terrace', 'NN'),
#  ('type', 'NN'),
#  (',', ','),
#  ('being', 'BEG'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('ground', 'NN'),
#  ('floor', 'NN'),
#  ('so', 'QL'),
#  ('that', 'CS'),
#  ('entrance', 'NN'),
#  ('is', 'BEZ'),
#  ('direct', 'JJ'),
#  ('.', '.')]

# %%
unigram_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.9245482228606466

# %%
brown_tagged_sents = brown.tagged_sents()

# %%
size = int(len(brown_tagged_sents)*0.9)
train_sents = brown_tagged_sents[:size]

# %%
test_sents = brown_tagged_sents[size:]

# %%
len(test_sents)
# Out:
# 5734

# %%
unigram_tagger = nltk.UnigramTagger(train_sents)
unigram_tagger.evaluate(test_sents)
# Out:
# 0.8849353534083527

# %%
# N-Gram tagging
bigram_tagger = nltk.BigramTagger(train_sents)
bigram_tagger.tag(brown_sents[2007])
# Out:
# [('Various', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('apartments', 'NNS'),
#  ('are', 'BER'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('terrace', 'NN'),
#  ('type', 'NN'),
#  (',', ','),
#  ('being', 'BEG'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('ground', 'NN'),
#  ('floor', 'NN'),
#  ('so', 'CS'),
#  ('that', 'CS'),
#  ('entrance', 'NN'),
#  ('is', 'BEZ'),
#  ('direct', 'JJ'),
#  ('.', '.')]

# %%
bigram_tagger.evaluate(test_sents) #unigram보다 정확도가 훨씬 떨어짐
# Out:
# 0.3515747783994468

# %% [markdown]
# -> unseen data가 너무 많기 때문에 오히려 성능이 떨어짐

# %%
t0 = nltk.DefaultTagger('NN')
t1 = nltk.UnigramTagger(train_sents, backoff=t0)
t2 = nltk.BigramTagger(train_sents, backoff=t1)
t2.evaluate(test_sents)
# Out:
# 0.9125751765470128

# %% [markdown]
# ---
# python - training한 모델 저장

# %%
from pickle import dump
output = open('t2.pkl', 'wb')
dump(t2, output, -1)
output.close()

# %%
from pickle import load
input = open('t2.pkl', 'rb')
tagger = load(input)
input.close()

# %% [markdown]
# ---

# %%
# confusion matrix
test_tags =[tag for sent in brown.sents(categories='editorial')
for (word, tag) in t2.tag(sent)]
gold_tags = [tag for (word, tag) in brown.tagged_words(categories='editorial')]
print(nltk.ConfusionMatrix(gold_tags, test_tags))
# Out:
#            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 P                                                                                                                                                                                                                        
# ...

# %% [markdown]
# Brill tagging : go back and fisx mistakes, make rule
#
# TNT tagger : n-gram 중 높은 probability인 것 선택
